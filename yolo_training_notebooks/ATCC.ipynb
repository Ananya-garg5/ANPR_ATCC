# %%
# !pip install "numpy<2.0" "opencv-python<4.11" "opencv-python-headless<4.11" ultralytics --quiet

print(" Environment configured successfully.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 49.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
#  Environment configured successfully.

# %%
# !pip install --no-deps ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.237)

# %%
import os
import json
import shutil
import yaml
from tqdm.notebook import tqdm
from ultralytics import YOLO
import glob
import random
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
BASE_DIR = "/kaggle/input/solesensei_bdd100k"
JSON_TRAIN = f"{BASE_DIR}/bdd100k_labels_release/bdd100k/labels/bdd100k_labels_images_train.json"
JSON_VAL   = f"{BASE_DIR}/bdd100k_labels_release/bdd100k/labels/bdd100k_labels_images_val.json"

IMG_TRAIN  = f"{BASE_DIR}/bdd100k/bdd100k/images/10k/train" 
IMG_VAL    = f"{BASE_DIR}/bdd100k/bdd100k/images/100k/val"

OUT_DIR = "/kaggle/working/atcc_dataset"
VALID_CLASSES = ["car", "truck", "bus", "motorcycle"]

if os.path.exists(OUT_DIR):
    shutil.rmtree(OUT_DIR)

for split in ['train', 'val']:
    os.makedirs(f"{OUT_DIR}/images/{split}", exist_ok=True)
    os.makedirs(f"{OUT_DIR}/labels/{split}", exist_ok=True)

# %%
def process_split(json_path, src_img_dir, split_name):
    """
    Reads BDD100K JSON labels and converts them to YOLO .txt format.
    Uses Symbolic Links for images to save disk space and time.
    """
    print(f"Processing {split_name}...")
    with open(json_path, 'r') as f:
        data = json.load(f)
    
    count = 0
    for item in tqdm(data, desc=f"Converting {split_name}"):
        filename = item['name']
        src_path = os.path.join(src_img_dir, filename)
        
        dst_img_path = f"{OUT_DIR}/images/{split_name}/{filename}"
        dst_lbl_path = f"{OUT_DIR}/labels/{split_name}/{filename.replace('.jpg', '.txt')}"

        if not os.path.exists(src_path): 
            continue

        labels = item.get('labels', [])
        valid_objs = [obj for obj in labels if obj['category'] in VALID_CLASSES]
        
        if not valid_objs: 
            continue

        try:
             os.symlink(src_path, dst_img_path)
        except FileExistsError:
            pass
            
        with open(dst_lbl_path, 'w') as out_f:
            for obj in valid_objs:
                cls_idx = VALID_CLASSES.index(obj['category'])
                box = obj['box2d']
                
                xc = ((box['x1'] + box['x2']) / 2) / 1280
                yc = ((box['y1'] + box['y2']) / 2) / 720
                w  = (box['x2'] - box['x1']) / 1280
                h  = (box['y2'] - box['y1']) / 720
                
                out_f.write(f"{cls_idx} {xc:.6f} {yc:.6f} {w:.6f} {h:.6f}\n")
        count += 1
    
    print(f"{split_name}: Successfully linked & labeled {count} images.")
    
process_split(JSON_TRAIN, IMG_TRAIN, "train") 
process_split(JSON_VAL,   IMG_VAL,   "val")
print("\n Data Preparation Complete. Ready for Training.")
# Out:
# Processing train...
# Converting train:   0%|          | 0/69863 [00:00<?, ?it/s]
# train: Successfully linked & labeled 2959 images.
# Processing val...
# Converting val:   0%|          | 0/10000 [00:00<?, ?it/s]
# val: Successfully linked & labeled 9904 images.
#
#  Data Preparation Complete. Ready for Training.

# %%
yaml_content = {
    'path': '/kaggle/working/atcc_dataset',  
    'train': 'images/train',                
    'val': 'images/val',                    
    'names': {0: 'car', 1: 'truck', 2: 'bus', 3: 'motorcycle'} 
}

with open('atcc.yaml', 'w') as f:
    yaml.dump(yaml_content, f)

model = YOLO('yolov8n.pt') 


model.train(
    data='atcc.yaml',
    epochs=30,         
    imgsz=640,
    batch=16,
    workers=0,         
    project='atcc_project',
    name='run_full_data',
    verbose=True
)

print(" Training successfully completed.")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 337.1MB/s 0.0s
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=atcc.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=run_full_data, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=atcc_project, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/atcc_project/run_full_data, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 87.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 129 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 283.7MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 6.6±2.2 MB/s, size: 59.5 KB)
# train: Scanning /kaggle/working/atcc_dataset/labels/train... 2959 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2959/2959 295.0it/s 10.0s
# train: New cache created: /kaggle/working/atcc_dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.5 ms, read: 6.6±1.6 MB/s, size: 55.6 KB)
# val: Scanning /kaggle/working/atcc_dataset/labels/val... 9904 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9904/9904 313.4it/s 31.6s
# val: New cache created: /kaggle/working/atcc_dataset/labels/val.cache
# Plotting labels to /kaggle/working/atcc_project/run_full_data/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /kaggle/working/atcc_project/run_full_data
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.37G      1.373      1.632      1.048        359        640: 100% ━━━━━━━━━━━━ 185/185 2.2it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.0it/s 1:44
#                    all       9904     108348        0.4      0.302      0.274      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.39G       1.32      1.104      1.043        287        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.1it/s 1:40
#                    all       9904     108348      0.412      0.346      0.305      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.41G       1.32      1.046      1.046        330        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348       0.39      0.329        0.3       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.42G      1.299     0.9803      1.038        269        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.438      0.349      0.332        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.44G       1.27     0.9373      1.029        302        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348       0.42      0.365      0.338      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.46G      1.252     0.9071      1.023        309        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:38
#                    all       9904     108348      0.479      0.361       0.37      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.48G      1.235     0.8793      1.017        401        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.488      0.365      0.367      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.49G      1.218     0.8586      1.009        321        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.508      0.378       0.39      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.51G      1.207      0.845      1.008        215        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.504      0.388      0.394      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.53G      1.192     0.8222      1.001        351        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.494      0.377       0.39      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.54G      1.192     0.8104      1.001        356        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.528      0.402      0.416      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.56G      1.191     0.8096     0.9993        320        640: 100% ━━━━━━━━━━━━ 185/185 2.2it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.0it/s 1:42
#                    all       9904     108348      0.524      0.393      0.409      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.58G      1.179      0.789     0.9943        274        640: 100% ━━━━━━━━━━━━ 185/185 2.2it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.551       0.39      0.419      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30       2.6G      1.165     0.7776       0.99        280        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:36
#                    all       9904     108348       0.54      0.425      0.442      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.61G      1.159     0.7651     0.9914        277        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:36
#                    all       9904     108348      0.524      0.404      0.422      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.62G      1.135     0.7448     0.9813        307        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:36
#                    all       9904     108348      0.582      0.413      0.444      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.65G      1.145     0.7532     0.9818        286        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.595      0.405      0.451      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.66G      1.133     0.7353     0.9751        396        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.1it/s 1:39
#                    all       9904     108348      0.564      0.415      0.449       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.68G      1.124     0.7262     0.9751        333        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:36
#                    all       9904     108348      0.577      0.423      0.454      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      2.69G      1.119     0.7218     0.9721        346        640: 100% ━━━━━━━━━━━━ 185/185 2.3it/s 1:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:36
#                    all       9904     108348      0.561       0.42      0.457      0.296
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.71G      1.141     0.7088     0.9726        201        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.591      0.412      0.456      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.73G      1.134     0.6958     0.9699        109        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:36
#                    all       9904     108348      0.593      0.433      0.474      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.75G      1.126     0.6842     0.9667        176        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:36
#                    all       9904     108348      0.598      0.427      0.473      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.76G      1.122     0.6808     0.9628        157        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:35
#                    all       9904     108348      0.593      0.423      0.472       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.78G      1.111     0.6678     0.9607        220        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:38
#                    all       9904     108348      0.603      0.426      0.477      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30       2.8G      1.108     0.6587     0.9579        202        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.3it/s 1:35
#                    all       9904     108348      0.583      0.439      0.478      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.82G        1.1     0.6495     0.9579        170        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.614      0.435      0.486       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.83G      1.092     0.6394     0.9498        158        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.599      0.441      0.484      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.85G       1.09     0.6355     0.9501        164        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:38
#                    all       9904     108348      0.607      0.443      0.488      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.87G      1.083     0.6288      0.952        148        640: 100% ━━━━━━━━━━━━ 185/185 2.4it/s 1:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.2it/s 1:37
#                    all       9904     108348      0.617      0.442      0.493      0.326
#
# 30 epochs completed in 1.492 hours.
# Optimizer stripped from /kaggle/working/atcc_project/run_full_data/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/atcc_project/run_full_data/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/atcc_project/run_full_data/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 310/310 3.0it/s 1:43
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all       9904     108348      0.617      0.441      0.493      0.326
#                    car       9879     102506      0.728      0.593      0.663      0.397
#                  truck       2689       4245      0.563      0.402      0.431      0.293
#                    bus       1242       1597      0.562      0.329      0.385      0.287
# Speed: 0.1ms preprocess, 1.3ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/atcc_project/run_full_data
#  Training successfully completed.

# %%
best_path = "/kaggle/working/atcc_project/run_full_data/weights/best.pt"
save_path = "/kaggle/working/output/best_atcc.pt" 

os.makedirs("/kaggle/working/output", exist_ok=True)
shutil.copy(best_path, save_path)

print("best.pt at:", save_path)
# Out:
# best.pt at: /kaggle/working/output/best_atcc.pt

# %%
from IPython.display import Image, display

print(" PERFORMANCE ANALYSIS")
print("=======================")

print("1. Training Metrics (Loss should decrease, mAP should increase):")
display(Image(filename=f'/kaggle/working/atcc_project/run_full_data/results.png'))

print("\n2. Confusion Matrix (Diagonal values should be high):")
print("   - Shows if the model confuses 'Bus' with 'Truck', etc.")
display(Image(filename=f'/kaggle/working/atcc_project/run_full_data/confusion_matrix.png'))
# Out:
#  PERFORMANCE ANALYSIS
# =======================
# 1. Training Metrics (Loss should decrease, mAP should increase):
# 2. Confusion Matrix (Diagonal values should be high):
#    - Shows if the model confuses 'Bus' with 'Truck', etc.

# %%
best_model = YOLO('/kaggle/working/atcc_project/run_full_data/weights/best.pt')

test_folder = "/kaggle/input/solesensei_bdd100k/bdd100k/bdd100k/images/100k/test"
test_images = glob.glob(f"{test_folder}/*.jpg")

selected_images = random.sample(test_images, 5)

print(f" Running ATCC System on {len(selected_images)} Test Images...\n")
classes = ["car", "truck", "bus", "motorcycle"]

for img_path in selected_images:
    results = best_model.predict(img_path, conf=0.35, verbose=False)[0]

    counts = {c: 0 for c in classes}
    
    det_classes = results.boxes.cls.cpu().numpy().astype(int)
    
    for cls_id in det_classes:
        c_name = results.names[cls_id]
        if c_name in counts:
            counts[c_name] += 1
            
    print(f" Image: {os.path.basename(img_path)}")
    print("-" * 30)
    print(f"   Car:        {counts['car']}")
    print(f"   Truck:      {counts['truck']}")
    print(f"    Bus:        {counts['bus']}")
    print(f"    Motorcycle: {counts['motorcycle']}")
  
    
    plt.figure(figsize=(12, 8))
    plt.imshow(results.plot()[:, :, ::-1])
    plt.axis('off')
    plt.show()
# Out:
#  Running ATCC System on 5 Test Images...
#
#  Image: d91f436f-eaf33daf.jpg
# ------------------------------
#    Car:        3
#    Truck:      0
#     Bus:        0
#     Motorcycle: 0
#  Image: f18fd70e-47c1f46e.jpg
# ------------------------------
#    Car:        3
#    Truck:      0
#     Bus:        0
#     Motorcycle: 0
#  Image: ed7b83b1-3ad9852f.jpg
# ------------------------------
#    Car:        5
#    Truck:      0
#     Bus:        0
#     Motorcycle: 0
#  Image: defdbb7e-08229ec4.jpg
# ------------------------------
#    Car:        2
#    Truck:      0
#     Bus:        0
#     Motorcycle: 0
#  Image: f6466550-359057ff.jpg
# ------------------------------
#    Car:        8
#    Truck:      0
#     Bus:        0
#     Motorcycle: 0
